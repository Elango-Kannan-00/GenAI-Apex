# %% [markdown]
# <a href="https://colab.research.google.com/github/Elango-Kannan-00/GenAI-Apex/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google.generativeai

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
key=userdata.get('GOOGLE_API_KEY')

# %%
model=genai.configure(api_key=key)

# %%
for i in genai.list_models():
     print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
model.generate_content("what is ARPANET ").text
# Out:
# 'ARPANET is an abbreviation for Advanced Research Projects Agency Network. It was the first operational packet-switching network, and its technology became the foundation for the modern Internet.\n\nARPANET was developed by the United States Advanced Research Projects Agency (ARPA) between 1969 and 1972 with a funding of $2 million. The primary goal was to create a network in which multiple computers could communicate on a single network.\n\nThe first ARPANET message was sent on October 29, 1969, from a computer at the University of California, Los Angeles (UCLA) to a computer at the Stanford Research Institute (SRI). The message consisted of the word "LOGIN" and was sent using a custom protocol called the Network Control Program (NCP).\n\nAfter the initial success, ARPANET\'s use expanded, including  the development of email, file transfer protocols (FTP), and other network applications. \n\nThe first network of networks (internetworking) was a set of interconnected ARPANETs. In 198
# ...

# %%
vision_model=genai.GenerativeModel("gemini-pro")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/content/AW-515456415.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1920>

# %%
vision_model1=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model1.generate_content(["What is in this image", Image.open("/content/AW-515456415.jpg")]).text
# Out:
# "That's a photo of a pedestrian bridge at night.\xa0\n\n\nHere's a breakdown of what's in the image:\n\n* **Bridge:** A modern, metal pedestrian bridge with railings spans a body of water.  The bridge is wet, suggesting rain.\n\n* **Lighting:** Several streetlights line the bridge, illuminating the walkway and reflecting in the wet surface.\n\n* **Water:** Dark water is visible beneath the bridge.\n\n* **Cityscape:** In the background, a cityscape is visible with buildings of varying heights.  The city appears somewhat distant.\n\n* **Sky:** The sky is a deep blue, indicative of twilight or early evening. There are a few clouds visible.\n\nThe overall mood of the image is serene, tranquil, and somewhat melancholic due to the dark blue tones and the quiet, empty scene.\n"

# %%
model_text=genai.GenerativeModel("gemini-1.5-flash")

# %%
print(model_text.generate_content(["Give poem for this image in 8 lines",img]).text)
# Out:
# City sleeps beneath a twilight sky,
# Lamplight paints the wet road's shine.
# A bridge extends, where shadows lie,
# Reflecting stars in watery line.
#
# Across the bay, the buildings gleam,
# A silent watch in indigo's hold.
# A lonely path, a quiet dream,
# A story in the night unfolds.
