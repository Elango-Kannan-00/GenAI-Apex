# %% [markdown]
# <a href="https://colab.research.google.com/github/Elango-Kannan-00/GenAI-Apex/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google.generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyCaMihtxHYDw9KZl_zyf4D6QTihRLpo4FQ")

# %%
for i in genai.list_models():
     print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
model.generate_content("what is ARPANET ").text
# Out:
# '**ARPANET (Advanced Research Projects Agency Network)**\n\n**Definition:**\nARPANET was the predecessor to the modern Internet, developed by the Advanced Research Projects Agency (ARPA) of the United States Department of Defense.\n\n**History:**\n* Initiated in 1969 as an experimental network to connect research institutions and government agencies.\n* Became operational in 1971 and evolved into the first network to use the TCP/IP protocol suite, which is still the foundation of the Internet today.\n\n**Key Features:**\n* **Packet-switching technology:** Divided data into smaller packets, allowing for efficient and reliable transmission over different paths.\n* **Decentralized design:** No central authority controlled the network, making it resilient and fault-tolerant.\n* **Internetworking:** Allowed different networks to connect and exchange data, laying the groundwork for the global Internet.\n\n**Importance:**\n* Served as a testbed for innovative network technologies that shaped the development of the Internet.\n* Introduced key concepts such as packet-switching, TCP/IP, and the domain name system (DNS).\n* Enabled the exchange of electronic mail, file transfers, and remote login sessions.\n* Pioneered the concept of a network of networks, which became the foundation of the global Internet.\n\n**Legacy:**\nARPANET was decommissioned in 1990, but its legacy lives on in the modern Internet. It:\n* Inspired the creation of the National Science Foundation Network (NSFNET), which connected major universities and research institutions.\n* Influenced the development of commercial Internet networks, leading to the widespread adoption of the Internet in the 1990s.\n* Established the principles and technologies that underpin the Internet we use today.'

# %%
vision_model=genai.GenerativeModel("gemini-pro-vision")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/content/image 2.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1225>

# %%
vision_model1=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model1.generate_content(["What is in this image", Image.open("/content/image 2.jpg")]).text
# Out:
# 'The image contains a surreal scene of a man standing in a desolate landscape facing a giant, textured model of a human brain.  The man is small in comparison to the brain, emphasizing its scale and significance. The sky is a muted teal and the overall tone is somewhat melancholic.  The image likely represents a concept related to the power and immensity of the human mind, or perhaps the overwhelming nature of thought.\n'

# %%
model_text=genai.GenerativeModel("gemini-1.5-flash")

# %%
print(model_text.generate_content(["Give poem for this image in 8 lines",img]).text)
# Out:
# A giant brain, a sandy hue,
# Looms large against a sky so blue.
# A lone man stands, a tiny speck,
# His gaze held fast, a silent check.
#
# The weight of thought, a massive form,
# A mystery, a silent storm.
# He stands and stares, small and alone,
# Before the mind's colossal throne.
